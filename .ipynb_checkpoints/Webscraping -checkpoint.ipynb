# %%
import requests 
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
data = requests.get(standings_url)

# %%
soup = BeautifulSoup(data.text)

# %%
standings_table = soup.select('table.stats_table')[0]

# %%
links = standings_table.find_all('a')

# %%
#standings_table.find_all('a')

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if '/squads/' in l]

# %%
links
# Out:
# ['/en/squads/18bb7c10/Arsenal-Stats',
#  '/en/squads/b8fd03ef/Manchester-City-Stats',
#  '/en/squads/361ca564/Tottenham-Hotspur-Stats',
#  '/en/squads/b2b47a98/Newcastle-United-Stats',
#  '/en/squads/cff3d9bb/Chelsea-Stats',
#  '/en/squads/19538871/Manchester-United-Stats',
#  '/en/squads/fd962109/Fulham-Stats',
#  '/en/squads/822bd0ba/Liverpool-Stats',
#  '/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats',
#  '/en/squads/cd051869/Brentford-Stats',
#  '/en/squads/d3fd31cc/Everton-Stats',
#  '/en/squads/47c64c55/Crystal-Palace-Stats',
#  '/en/squads/4ba7cbea/Bournemouth-Stats',
#  '/en/squads/8602292d/Aston-Villa-Stats',
#  '/en/squads/33c895d4/Southampton-Stats',
#  '/en/squads/a2d435b3/Leicester-City-Stats',
#  '/en/squads/7c21e445/West-Ham-United-Stats',
#  '/en/squads/5bfb9659/Leeds-United-Stats',
#  '/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats',
#  '/en/squads/e4a775cb/Nottingham-Forest-Stats']

# %%
team_urls= [f"https://fbre.com{l}" for l in links]

# %%
team_urls
# Out:
# ['https://fbre.com/en/squads/18bb7c10/Arsenal-Stats',
#  'https://fbre.com/en/squads/b8fd03ef/Manchester-City-Stats',
#  'https://fbre.com/en/squads/361ca564/Tottenham-Hotspur-Stats',
#  'https://fbre.com/en/squads/b2b47a98/Newcastle-United-Stats',
#  'https://fbre.com/en/squads/cff3d9bb/Chelsea-Stats',
#  'https://fbre.com/en/squads/19538871/Manchester-United-Stats',
#  'https://fbre.com/en/squads/fd962109/Fulham-Stats',
#  'https://fbre.com/en/squads/822bd0ba/Liverpool-Stats',
#  'https://fbre.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats',
#  'https://fbre.com/en/squads/cd051869/Brentford-Stats',
#  'https://fbre.com/en/squads/d3fd31cc/Everton-Stats',
#  'https://fbre.com/en/squads/47c64c55/Crystal-Palace-Stats',
#  'https://fbre.com/en/squads/4ba7cbea/Bournemouth-Stats',
#  'https://fbre.com/en/squads/8602292d/Aston-Villa-Stats',
#  'https://fbre.com/en/squads/33c895d4/Southampton-Stats',
#  'https://fbre.com/en/squads/a2d435b3/Leicester-City-Stats',
# ...

# %%
team_url ='https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats'

# %%
team_url
# Out:
# 'https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats'

# %%
data = requests.get(team_url)

# %%
matches= pd.read_html(data.text, match="Scores & Fixtures")

# %%
matches[0].head()
# Out:
#          Date   Time            Comp        Round  Day Venue Result   GF   GA  \
# 0  2022-08-06  17:30  Premier League  Matchweek 1  Sat  Away      W  1.0  0.0
# 1  2022-08-14  16:30  Premier League  Matchweek 2  Sun  Home      D  2.0  2.0
# 2  2022-08-21  14:00  Premier League  Matchweek 3  Sun  Away      L  0.0  3.0
# 3  2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-30  19:45  Premier League  Matchweek 5  Tue  Away      L  1.0  2.0
#
#          Opponent   xG  xGA  Poss  Attendance            Captain Formation  \
# 0         Everton  1.6  0.5  62.0     39254.0  César Azpilicueta     3-4-3
# 1       Tottenham  1.4  1.1  65.0     39946.0           Jorginho     3-4-3
# 2    Leeds United  0.7  1.9  61.0     36372.0           Jorginho     3-4-3
# 3  Leicester City  1.9  1.7  46.0     39953.0           Jorginho     4-4-2
# 4     Southampton  1.2  0.8  66.0     31542.0  César Azpilicueta   4-2-2-2
#
#           Referee  Match Report Notes
# ...

# %%
# shooting stats
soup = BeautifulSoup(data.text)

# %%
links = soup.find_all('a')

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if l and 'all_comps/shooting/' in l]

# %%
links
# Out:
# ['/en/squads/cff3d9bb/2022-2023/matchlogs/all_comps/shooting/Chelsea-Match-Logs-All-Competitions',
#  '/en/squads/cff3d9bb/2022-2023/matchlogs/all_comps/shooting/Chelsea-Match-Logs-All-Competitions',
#  '/en/squads/cff3d9bb/2022-2023/matchlogs/all_comps/shooting/Chelsea-Match-Logs-All-Competitions',
#  '/en/squads/cff3d9bb/2022-2023/matchlogs/all_comps/shooting/Chelsea-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbre.com{links[0]}")

# %%
chelsea_url='https://fbref.com/en/squads/cff3d9bb/2022-2023/matchlogs/all_comps/shooting/Chelsea-Match-Logs-All-Competitions'

# %%
chelsea_url
# Out:
# 'https://fbref.com/en/squads/cff3d9bb/2022-2023/matchlogs/all_comps/shooting/Chelsea-Match-Logs-All-Competitions'

# %%
data_package = requests.get(chelsea_url)

# %%
shooting = pd.read_html(data_package.text, match="Shooting")[0]

# %%
shooting
# Out:
#    For Chelsea                                                                 \
#           Date   Time            Comp         Round  Day Venue Result  GF  GA
# 0   2022-08-06  17:30  Premier League   Matchweek 1  Sat  Away      W   1   0
# 1   2022-08-14  16:30  Premier League   Matchweek 2  Sun  Home      D   2   2
# 2   2022-08-21  14:00  Premier League   Matchweek 3  Sun  Away      L   0   3
# 3   2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W   2   1
# 4   2022-08-30  19:45  Premier League   Matchweek 5  Tue  Away      L   1   2
# 5   2022-09-03  15:00  Premier League   Matchweek 6  Sat  Home      W   2   1
# 6   2022-09-06  18:45    Champions Lg   Group stage  Tue  Away      L   0   1
# 7   2022-09-14  20:00    Champions Lg   Group stage  Wed  Home      D   1   1
# 8   2022-10-01  15:00  Premier League   Matchweek 9  Sat  Away      W   2   1
# 9   2022-10-05  20:00    Champions Lg   Group stage  Wed  Home      W   3   0
# ...

# %% [markdown]
# ### Cleaning and merging scraped data with Pandas

# %%
#shooting.head()

# %%
drop upper row
shooting.columns =shooting.columns.droplevel()

# %%
shooting.head()
# Out:
#          Date   Time            Comp        Round  Day Venue Result  GF  GA  \
# 0  2022-08-06  17:30  Premier League  Matchweek 1  Sat  Away      W   1   0
# 1  2022-08-14  16:30  Premier League  Matchweek 2  Sun  Home      D   2   2
# 2  2022-08-21  14:00  Premier League  Matchweek 3  Sun  Away      L   0   3
# 3  2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W   2   1
# 4  2022-08-30  19:45  Premier League  Matchweek 5  Tue  Away      L   1   2
#
#          Opponent  ...  Dist  FK  PK  PKatt   xG  npxG  npxG/Sh  G-xG  \
# 0         Everton  ...  16.2   1   1      1  1.6   0.9     0.07  -0.6
# 1       Tottenham  ...  16.7   0   0      0  1.4   1.4     0.09   0.6
# 2    Leeds United  ...  18.8   0   0      0  0.7   0.7     0.05  -0.7
# 3  Leicester City  ...  13.7   0   0      0  1.9   1.9     0.27   0.1
# 4     Southampton  ...  13.8   0   0      0  1.2   1.2     0.12  -0.2
#
#    np:G-xG  Match Report
# 0     -0.9  Match Report
# 1      0.6  Match Report
# ...

# %%
matches[0].head()
# Out:
#          Date   Time            Comp        Round  Day Venue Result   GF   GA  \
# 0  2022-08-06  17:30  Premier League  Matchweek 1  Sat  Away      W  1.0  0.0
# 1  2022-08-14  16:30  Premier League  Matchweek 2  Sun  Home      D  2.0  2.0
# 2  2022-08-21  14:00  Premier League  Matchweek 3  Sun  Away      L  0.0  3.0
# 3  2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-30  19:45  Premier League  Matchweek 5  Tue  Away      L  1.0  2.0
#
#          Opponent   xG  xGA  Poss  Attendance            Captain Formation  \
# 0         Everton  1.6  0.5  62.0     39254.0  César Azpilicueta     3-4-3
# 1       Tottenham  1.4  1.1  65.0     39946.0           Jorginho     3-4-3
# 2    Leeds United  0.7  1.9  61.0     36372.0           Jorginho     3-4-3
# 3  Leicester City  1.9  1.7  46.0     39953.0           Jorginho     4-4-2
# 4     Southampton  1.2  0.8  66.0     31542.0  César Azpilicueta   4-2-2-2
#
#           Referee  Match Report Notes
# ...

# %%
# merge the two tables

chelsea_data = matches[0].merge(shooting[["Date","Sh","SoT","Dist","FK","PK","PKatt"]], on="Date")

# %%
chelsea_data.head()
# Out:
#          Date   Time            Comp        Round  Day Venue Result   GF   GA  \
# 0  2022-08-06  17:30  Premier League  Matchweek 1  Sat  Away      W  1.0  0.0
# 1  2022-08-14  16:30  Premier League  Matchweek 2  Sun  Home      D  2.0  2.0
# 2  2022-08-21  14:00  Premier League  Matchweek 3  Sun  Away      L  0.0  3.0
# 3  2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-30  19:45  Premier League  Matchweek 5  Tue  Away      L  1.0  2.0
#
#          Opponent  ...  Formation         Referee  Match Report  Notes  Sh  \
# 0         Everton  ...      3-4-3    Craig Pawson  Match Report    NaN  14
# 1       Tottenham  ...      3-4-3  Anthony Taylor  Match Report    NaN  16
# 2    Leeds United  ...      3-4-3  Stuart Attwell  Match Report    NaN  14
# 3  Leicester City  ...      4-4-2    Paul Tierney  Match Report    NaN   7
# 4     Southampton  ...    4-2-2-2  Michael Oliver  Match Report    NaN  10
#
#   SoT  Dist FK PK  PKatt
# ...

# %%
# drop Notes
chelsea_data.drop(['Notes'],axis=1, inplace=True)

# %%
chelsea_data.head()
# Out:
#          Date   Time            Comp        Round  Day Venue Result   GF   GA  \
# 0  2022-08-06  17:30  Premier League  Matchweek 1  Sat  Away      W  1.0  0.0
# 1  2022-08-14  16:30  Premier League  Matchweek 2  Sun  Home      D  2.0  2.0
# 2  2022-08-21  14:00  Premier League  Matchweek 3  Sun  Away      L  0.0  3.0
# 3  2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-30  19:45  Premier League  Matchweek 5  Tue  Away      L  1.0  2.0
#
#          Opponent  ...            Captain  Formation         Referee  \
# 0         Everton  ...  César Azpilicueta      3-4-3    Craig Pawson
# 1       Tottenham  ...           Jorginho      3-4-3  Anthony Taylor
# 2    Leeds United  ...           Jorginho      3-4-3  Stuart Attwell
# 3  Leicester City  ...           Jorginho      4-4-2    Paul Tierney
# 4     Southampton  ...  César Azpilicueta    4-2-2-2  Michael Oliver
#
#    Match Report  Sh SoT  Dist FK  PK  PKatt
# ...

# %%
shooting.shape
# Out:
# (16, 26)

# %%
matches[0].shape
# Out:
# (45, 19)

# %%
chelsea_data.shape
# Out:
# (15, 24)

# %% [markdown]
# ### Scraping multiple teams with a loop

# %%
years = list(range(2023,2021, -1))
years
# Out:
# [2023, 2022]

# %%
all_matches = []
