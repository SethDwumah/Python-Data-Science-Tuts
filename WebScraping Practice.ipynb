# %%
from bs4 import BeautifulSoup
import requests

# %%
import html5lib

# %%
import pandas as pd

# %%
energy_link = "https://www.livescore.com/en/"

# %%
data = requests.get(energy_link)

# %%
soup = BeautifulSoup(data.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
data_links = soup.find_all('a')

# %%
data_links
# Out:
# [<a href="/en/"><span class="al"><img alt="livescore logo" height="19" loading="lazy" src="/ls-web-assets/svgs/common/livescore-logo-b3b211143dccd9e22d164701d32a390f.svg" style="background-image:url(...)" width="104"/></span></a>,
#  <a class="Xd th" href="/en/" id="active-news-sport-navigation-link-football">Football</a>,
#  <a class="th" href="/en/hockey/" id="news-sport-navigation-link-hockey">Hockey</a>,
#  <a class="th" href="/en/basketball/" id="news-sport-navigation-link-basketball">Basketball</a>,
#  <a class="th" href="/en/tennis/" id="news-sport-navigation-link-tennis">Tennis</a>,
#  <a class="th" href="/en/cricket/" id="news-sport-navigation-link-cricket">Cricket</a>,
# ...

# %%
links = [l.get("href") for l in data_links]

# %%
links
# Out:
# ['/en/',
#  '/en/',
#  '/en/hockey/',
#  '/en/basketball/',
#  '/en/tennis/',
#  '/en/cricket/',
#  '/en/football/england/',
#  '/en/football/spain/',
#  '/en/football/italy/',
#  '/en/football/germany/',
#  '/en/football/france/',
#  '/en/football/holland/',
#  '/en/football/scotland/',
#  '/en/football/champions-league/',
#  '/en/football/europa-league/',
#  '/en/football/europa-conference-league/',
#  '/en/football/world-cup/',
#  '/en/football/world-cup-qualification/',
#  '/en/football/euro-2024-qualification/',
#  '/en/football/intl/',
#  '/en/football/uefa-nations-league/',
#  '/en/football/uefa-women-s-champions-league/',
#  '/en/football/womens-world-cup/',
#  '/en/football/euro-women/',
#  '/en/football/womens-world-cup-u20/',
#  '/en/football/womens-world-cup-u17/',
#  '/en/football/uefa-youth-league/',
#  '/en/football/euro-under-21/',
#  '/en/football/euro-u-19-2021/',
#  '/en/football/euro-under-17/',
#  '/en/football/africa-cup-of-nations-qualification/',
# ...

# %%
lins = [l for l in links if '/football/' in l]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 lins = [l for l in links if '/football/' in l]
#
# Input In [39], in <listcomp>(.0)
# ----> 1 lins = [l for l in links if '/football/' in l]
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
lins
# Out:
# []

# %%
data_sets = [f"https://www.iea.org{l}" for l in lins ]

# %%
data_sets
# Out:
# ['https://www.iea.org/data-and-statistics/data-sets',
#  'https://www.iea.org/data-and-statistics/charts',
#  'https://www.iea.org/data-and-statistics/about',
#  'https://www.iea.org/data-and-statistics/data-sets/?filter=',
#  'https://www.iea.org/data-and-statistics/data-sets/?filter=balances%2Fstatistics',
#  'https://www.iea.org/data-and-statistics/data-sets/?filter=coal',
#  'https://www.iea.org/data-and-statistics/data-sets/?filter=efficiency',
#  'https://www.iea.org/data-and-statistics/data-sets/?filter=electricity',
#  'https://www.iea.org/data-and-statistics/data-sets/?filter=emissions',
#  'https://www.iea.org/data-and-statistics/data-sets/?filter=free',
#  'https://www.iea.org/data-and-statistics/data-sets/?filter=gas',
#  'https://www.iea.org/data-and-statistics/data-sets/?filter=oil',
#  'https://www.iea.org/data-and-statistics/data-sets/?filter=other',
#  'https://www.iea.org/data-and-statistics/data-sets/?filter=prices',
# ...

# %%
data_set_link = data_sets[0]

# %%
data_set_link
# Out:
# 'https://www.iea.org/data-and-statistics/data-sets'

# %%
data = requests.get(data_set_link)

# %%
for link in soup.find_all('a'):
    print(link.get("href"))
# Out:
# 1
# https://www.iea.org
# https://www.iea.org
# #content
# /countries
# /countries
# /world
# /countries/australia
# /countries/austria
# /countries/belgium
# /countries/canada
# /countries/czech-republic
# /countries/denmark
# /countries/estonia
# /countries/finland
# /countries/france
# /countries/germany
# /countries/greece
# /countries/hungary
# /countries/ireland
# /countries/italy
# /countries/japan
# /countries/korea
# /countries/lithuania
# /countries/luxembourg
# /countries/mexico
# /countries/new-zealand
# /countries/norway
# /countries/poland
# /countries/portugal
# /countries/slovak-republic
# /countries/spain
# /countries/sweden
# /countries/switzerland
# /countries/the-netherlands
# /countries/turkiye
# /countries/united-kingdom
# /countries/united-states
# /countries/argentina
# /countries/brazil
# /countries/china
# /countries/egypt
# /countries/india
# /countries/indonesia
# /countries/morocco
# /countries/singapore
# /countries/south-africa
# /countries/thailand
# ...
